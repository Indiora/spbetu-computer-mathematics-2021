# %% [markdown]
# # Практическая работа №2: Исследование задач о раскрасках
#
# Выполнил Прибылов Н.А., студент гр. 9381, вариант 59
#
# ## Цель работы
#
# Формирование представления о задачах о раскрасках, выработать умение использование леммы Бёрнсайда для решения задачи о раскрасках, привить навык использования систем компьютерной алгебры для реализации алгоритмов решения задачи.
#
# ## Основные теоретические положения
#
# ### Действие группы на множество
#
# Пусть $G$ - группа, $X$ - множество. Говорят, что $G$ действует на $X$, если задана операция $G \times X \to X$, обладающая следующими свойствами:
# $\forall x \in X$ и $\forall g,h \in G$
# 1) $g(hx) = (gh)x$
# 2) $ex = x$
#
#
# ### Орбиты и неподвижные точки
#
# Орбитой $x \in X$ под действием $G$ называется множество из элементов, в которые переходят $x$ под действием $G$.
# $Gx = \{gx | g \in G\}$.
# Длина орбиты - количество элементов в орбите. Любые две орбиты либо не пересекаются, либо совпадают.
#
# Множество неподвижных точек элемента $g \in G$ - это такие $x \in X$, которые под действием элемента не изменяются.
# $X^g = \{x\in X | gx = x\}$
#
# ### Лемма Бёрнсайда
#
# Количество орбит действия группы $G$ на множестве $X$:
# $N = \frac{1}{|G|}\sum_{g \in G} |X^{g}|$
#
# ### Раскраски
#
# Пусть $I$ - произвольное множество, $C$ - множество цветов. Раскраской $I$ называется отображение $I$ в $C$. Множество всех раскрасок обозначим как $C^I$.
#
# Количество раскрасок из $C^{I}$, не меняющиеся под действием $g \in G$ равно $|C|^{c(\varphi(g))}$, где:
# $c(\varphi(g))$ - количество независимых циклов в перестановке $\varphi(g)$ (включая циклы длины 1).
#
# ## Постановка задачи
#
# Аналитически решить задачу о раскрасках; графически отобразить решения задачи с использованием системы компьютерной алгебры SageMath. Полученные результаты содержательно проинтерпретировать.
#
# ## Условие задачи
#
# Каждая сторона квадрата разбита на 7 равных частей и через точки деления проведены отрезки, параллельные сторонам квадрата. В получившиеся клеточки вставляют цветные стёкла 5 различных цветов. Сколькими способами можно составить такую мозаику (с точностью до поворотов и осевых симметрий квадрата)?
#
# ## Порядок выполнения работы
#
# 1) Аналитически решить задачу о раскрасках для заданного варианта. Все умозаключения в ходе решения обосновать и содержательно проинтерпретировать.
# 2) Реализовать средствами SageMath функцию, отображающую графически раскраску по заданному номеру. Продемонстрировать работу функции на нескольких примерах. Сделать выводы.
# 3) *Дополнительное необязательное задание: для заданного варианта решить задачу в общем виде.*
#
#
# ## Выполнение работы
#
# Симметрии квадрата описывает группа $D_8$ (иногда записывают как $D_4$), порядок которой - 8. Перечислим все симметрии:
# 1) $e$ - тождественное отображение,
# 2) $r$ - поворот на 90 градусов,
# 3) $r^2$ - поворот на 180 градусов,
# 4) $r^3$ - поворот на 270 градусов,
# 5) $s$ - отражение относительно вертикальной оси,
# 6) $sr$ - отражение относительно побочной диагонали,
# 7) $sr^2$ - отражение относительно горизонтальной оси,
# 8) $sr^3$ - отражение относительно главной диагонали.
#
# Необходимо для каждого элемента из $D_8$ найти количество независимых циклов.
# Количество клеточек в квадрате - 49. Заметим, что центральная клеточка никогда не будет покидать своего места, и будет являться циклом длины 1 во всех симметриях.
# 1) $e$: очевидно, что количество независимых циклов равно количеству клеточек - $49$.
# 2) $r$: легко заметить, что все циклы, кроме одного, будут состоять из 4 элементов, т.к. поворот на 90 градусов "прокручивает" четвёрки клеточек на 1 позицию; последний цикл, длины 1, состоит из центрального элемента. Итого $1+(49-1)/4=13$ циклов.
# 3) $r^2$:  если проследить за движением клеточек, можно выделить пары, переходящие друг в друга относительно центрального элемента. Сам центральный остаётся на месте. Итого $1+(49-1)/2=25$ циклов.
# 4) $r^3$: здесь применимы те же рассуждения, что и для $r$. $13$ циклов.
# 5) $s$: нетрудно увидеть, что большинство элементов можно выделить в пары, которые переходят друг в друга при вертикальном отражении. Остальные элементы, находящиеся прямо на вертикальной оси, остаются на местах, образуют 7 циклов длины 1. Итого $7+(49-7)/2=28$ циклов.
# 6) 7) 8) $sr, sr^2, sr^3$: здесь применимы те же рассуждения, что и для $s$ - меняется лишь ось симметрии. Итого 3 раза по $28$ циклов.
#
#
# Таким образом, согласно лемме Бёрнсайда,
# $N = \frac{1}{8}(5^{49} + 2*5^{13} + 5^{25} + 4*5^{28})$ - количество различных способов составить мозайку размера 7x7 из стёкол 5 различных цветов с точностью до поворотов и симметрий.
#
#
# ### Графическое представление симметрий

# %%
import random
from sage.plot.matrix_plot import MatrixPlot

def print_matrix(matrix):
    for i in range(size):
        print(matrix[i])

        
def rotated(matrix):
    return [list(r) for r in zip(*matrix[::-1])]


def reflected(matrix):
    return [list(reversed(r)) for r in matrix]
        
    
def draw_symmetries(matrix):
    colors = "Set1"
    print("Симметрии рандомной мозаики:")
    print("Тождественное отображение:")
    matrix_plot(matrix, cmap=colors).show(fontsize=10)
    print("Поворот на 90:")
    matrix_plot(rotated(matrix), cmap=colors).show(fontsize=10)
    print("Поворот на 180:")
    matrix_plot(rotated(rotated(matrix)), cmap=colors).show(fontsize=10)
    print("Поворот на 270:")
    matrix_plot(rotated(rotated(rotated(matrix))), cmap=colors).show(fontsize=10)
    print("Отражение относительно вертикали:")
    matrix_plot(reflected(matrix), cmap=colors).show(fontsize=10)
    print("Отражение относительно побочной диагонали:")
    matrix_plot(rotated(reflected(matrix)), cmap=colors).show(fontsize=10)
    print("Отражение относительно горизонтали::")
    matrix_plot(rotated(rotated(reflected(matrix))), cmap=colors).show(fontsize=10)
    print("Отражение относительно главной диагонали:")
    matrix_plot(rotated(rotated(rotated(reflected(matrix)))), cmap=colors).show(fontsize=10)
    
    
def illustrate_r():
    colors = "Set1"
    print("Иллюстрация четвёрок под действием r:")
    matrix = [[5 for j in range(size)] for i in range(size)]
    matrix[size//2][size//2] = 6
    matrix[1][2] = 1
    matrix[2][size-2] = 2
    matrix[size-3][1] = 3
    matrix[size-2][size-3] = 4
    matrix_plot(matrix, cmap=colors).show(fontsize=10)
    matrix_plot(rotated(matrix), cmap=colors).show(fontsize=10)
    
    
def illustrate_r2():
    colors = "Set1"
    print("Иллюстрация пар под действием r^2:")
    matrix = [[5 for j in range(size)] for i in range(size)]
    matrix[size//2][size//2] = 6
    matrix[1][2] = 1
    matrix[2][size-2] = 1
    matrix[size-3][1] = 2
    matrix[size-2][size-3] = 2
    matrix_plot(matrix, cmap=colors).show(fontsize=10)
    matrix_plot(rotated(rotated(matrix)), cmap=colors).show(fontsize=10)
    
    
def illustrate_s():
    colors = "Set1"
    print("Иллюстрация пар под действием s:")
    matrix = [[5 for j in range(size)] for i in range(size)]
    for i in range(size):
        matrix[i][size//2] = 6
    matrix[1][2] = 1
    matrix[2][size-2] = 1
    matrix[size-3][1] = 2
    matrix[size-2][size-3] = 2
    matrix_plot(matrix, cmap=colors).show(fontsize=10)
    matrix_plot(reflected(matrix), cmap=colors).show(fontsize=10)
    
    
size = 7
matrix = []
for i in range(size):
    currRow = []
    for j in range(1, size + 1):
        currRow.append(random.randint(15, 19))
    matrix.append(currRow)

    
illustrate_r()
illustrate_r2()
illustrate_s()
draw_symmetries(matrix)
# Out:
# Иллюстрация четвёрок под действием r:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive
# Иллюстрация пар под действием r^2:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive
# Иллюстрация пар под действием s:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive
# Симметрии рандомной мозаики:
# Тождественное отображение:
# Graphics object consisting of 1 graphics primitive
# Поворот на 90:
# Graphics object consisting of 1 graphics primitive
# Поворот на 180:
# Graphics object consisting of 1 graphics primitive
# Поворот на 270:
# Graphics object consisting of 1 graphics primitive
# Отражение относительно вертикали:
# Graphics object consisting of 1 graphics primitive
# Отражение относительно побочной диагонали:
# Graphics object consisting of 1 graphics primitive
# Отражение относительно горизонтали::
# ...

# %% [markdown]
# ## Выводы
#
# Были изучены элементы теории групп, в частности действия групп на множествах. Была применена лемма Бернсайда для установления количества различных раскрасок заданного множества, а также были улучшены навыки пользования системой компьютерной алгебры.
