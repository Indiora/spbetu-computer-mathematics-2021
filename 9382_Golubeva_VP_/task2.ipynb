# %% [markdown]
# # Практическая работа №2: Исследование задач о раскрасках
# Выполнила студентка группы 9382 Голубева Валентина, вариант 70
# ## Цель работы
# Формирование представления о задачах о раскрасках, выработать умение использование леммы Бёрнсайда для решения задачи о раскрасках, привить навык использования систем компьютерной алгебры для реализации алгоритмов решения задачи.
#
# ## Постановка задачи
# Аналитически решить задачу о раскрасках; графически отобразить решения задачи с использованием системы компьютерной алгебры $SageMath$. Полученные результаты содержательно проинтерпретировать.
#
# ## Порядок выполнения работы
# 1) Аналитически решить задачу о раскрасках для заданного варианта. Все умозаключения в ходе решения обосновать и содержательно проинтерпретировать.
# 2) Реализовать средствами $SageMath$ функцию, отображающую графически раскраску по заданному номеру. Продемонстрировать работу функции на нескольких примерах. Сделать выводы.
# 3) Дополнительное необязательное задание: для заданного варианта решить задачу в общем виде.
#
# ## Задание
# Вариант $70$
# Сколькими способами можно составить бусы из $51$ бусинок $5$-ти различных цветов(с точностью до поворотов и осевых симметрий?)
#
# ## Основные теоретические положения
# ***Def. 1*** пусть $G$ - группа, $e$ -  нейтральный элемент группы $G$, $X$ - множество. Тогда $G$ действует на $X$, если задана операция $G x X -> G$. Тогда $\forall x \in X$,  $\forall g,h \in G$: 1)$ex=x$, 2) $g(hx)=(gh)x$
#
# ***Def. 2*** *орбитой* элемента $ x \in X$ под действием $G$ называется множество $Gx=\{gx|g \in G\}$. Количество элементов в этом множестве называется длиной орбиты.
#
# ***Def. 3*** *неподвижными точками* $ g \in G: x \in X: gx = x$. $X^g$ - множество неподвижных точек элемента $g$.
#
# ***Лемма Бёрнсайда***
# Количество орбит действия группы $G$ на множество $X$ вычисляется по формуле: $N= \frac{1}{_{\#G}} \cdot \sum_{g \in G}\# X^g $
#
# ***Def. 4*** пусть $I$ - произвольное множество, $C$ - множество цветов. *Раскраской* множетсва $I$ называется функция $I->G$. $C^I$ - множество всех раскрасок. $\# C^I=(\#C)^{\#I}$
#
# ***Def. 5*** пусть $G$ - группа, действует на множестве $I$, тогда $gf(i)=f(g^{-1}i)$, где $g \in G, i \in I, f \in C^I$ задаёт действие $G$ на множество $C^I$
#
# ***Лемма 2***
# Для элемента $g \in G$ и функци $f \in C^I$ следующие условия эквивалентны:
# * $gf = f$
# * $f(i)=f(g^ni), \forall i \in I, n \in Z$
# * если $i, j \in I$ лежат в одном цикле в циклической записи в перестановке $\alpha(g)$, то $f(i)=f(j)$
#
# ***Def. 6*** Количество раскрасок $C^I$, которые сохраняют $g \in G$ равно $(\# C)^{C(\alpha(g))}$, где $C$ - количество независимых циклов в записи перестановки

# %% [markdown]
# ## Выполнение работы
# Имеем набор бусинок $\{x_1, x_2,...,x_{51}\}$, гду $x_i$ окрашена в один из цветов набора $\{a,b,c,d,e\}$. Общее количество бус, которое может получиться - $5^{51}$. Однако в этом количестве бус много повторяющихся.
# На множестве определены операции - поворот по ч.с. и осевая симметрия.
# Пример поворота. Допустим, у нас есть некоторые бусы из пяти бусинок. На первом месте стоит синяя бусинка, на втором - желтая, а на остальных - красные. При повороте по ч.с. на первом месте будет стоять красная бусинка, на втором - синяя, на третьем - желтая, а на остальных - красные.
# Пример симметрии. Допустим, у нас есть некоторые бусы из шести бусинок -
# $(-1-2-3-4-5-6-)$ при симметрии относительно оси, проходящей между $6-1$, $4-3$ получаются бусы $(-6-5-4-3-2-1)$
#
# Группа $G$ действует на множестве мест $\{1, 2, ..., 51\}$. Задано отображение из $G$ в симметрическую группу $S_{51}$
#
# На множестве введено тождественное преобразование, запишем его в виде перестановки:
# $e = \begin{pmatrix}
# 1 & 2 & ... & 51 \\\
# 1 & 2 & ... & 51
# \end{pmatrix} = (1)(2)...(51)$
#
# $\tau$ - поворот, переводящий каждую бусинку в следующую
# $\sigma$ - осевая симметрия
#
# Так как на данном множестве действует количестdj перестановок большое для того, чтобы выписывать все из них, выпишем несколько из них
#
# $\tau = \begin{pmatrix}
# 1 & 2 & ... & 51 \\\
# 2 & 3 & ... & 1
# \end{pmatrix} = (1 \ 2 ... 51)$
#
# $\tau^2 = \begin{pmatrix}
# 1 & 2 & ... & 51 \\\
# 3 & 4 & ... & 2
# \end{pmatrix} = (1 \ 3 ... 49 \ 51)(2 \ 4 ...  48 \ 50)$
#
# ...
#
# $\sigma = \begin{pmatrix}
# 1 & 2 & ...& 50 & 51 \\\
# 51 & 50 & ... & 2 & 1
# \end{pmatrix} = (1 \ 51)(2 \ 50)...(46 \ 48)(49)$
#
# $\sigma^2 = e$
#
# Перестановка $\tau$ - цикл длины 51. По лемме 2 посчитаем количество циклов в перестановках $\tau^i \forall i$. Разложим $51$ на простые множители: $51 = 17*3$. $\tau^i$ является произведением из $d$ независимых циклов, где $d$=НОД($51, i$). Тогда для всех $i$ не кратных $17$ или $3$ $d$ будет иметь значение $1$.
#
# Перестановка $\sigma$ - произведение $26$ независимых циклов. По определению $6$ это количество элементов из множества $X$, которые оставляют на месте каждый элемент группы $G$. После применения к перестановке $\sigma \ \tau^i$ результатом будет также произведение $26$-ти независимых циклов. Это происходит в силу симметрии структуры перестановки.
#
# Раскраски будут задавать одинаковые бусы тогда и только тогда, когда они лежат в одной орбите под действием $G$. Нужно вычислить количество орбит действия $G$ на $X$.
#
# $|X^e| \ = \ 5^{51}$
# $|X^{\tau^i}| = 5^1$, где $i \in \{1..50\},$ исключая $i\%17 = 0$ и $i\%3 = 0$
# $|X^{\tau^{3}}| = |X^{\tau^{6}}| = |X^{\tau^{9}}| = ... = |X^{\tau^{48}}| = 5^{3}$
# $|X^{\tau^{17}}| = |X^{\tau^{34}}| = 5^{17}$
# $|X^{\sigma}| = |X^{\sigma \tau}| = |X^{\sigma \tau^2}| = ... = |X^{\sigma \tau^{50}}| = 5^{26}$
# $|G| = 102$
#
# Тогда по лемме Бёрнсайда посчитаем количество различных бус:
# кол-во различных бус = $\frac{1}{102}(5^{51} + 32*5^{1} + 16*5^{3} + 2*5^{17} + 51*5^{26})$

# %%
def tau(necklace):
    return necklace[1:] + necklace[:1]

def sigma(beads):
    return [beads[-i] for i in range(1,52)]    

def get_necklace_color(num):
    return ['purple', 'cyan', 'blue', 'grey', 'pink'][num-1]

def print_necklace(necklace):
    graph = graphs.CycleGraph(51)
    graph.relabel({i:necklace[i][0] for i in range(51)})
    colors={ 'purple':[], 'cyan':[], 'blue':[], 'grey':[], 'pink':[] }
    for i in necklace:
        colors[get_necklace_color(i[1])].append(i[0])
    fig=graph.graphplot(vertex_colors=colors)
    fig.show(figsize=[5,5])
    
import random  

start_necklace = []
for i in range(1,52):
    start_necklace.append([i, random.randint(1,5)])    
print('Стартовые бусы')
print_necklace(start_necklace)
# Out:
# Стартовые бусы
# Graphics object consisting of 103 graphics primitives

# %%
print('Применим операцию симметричного отображения')
print_necklace(sigma(start_necklace))
# Out:
# Применим операцию симметричного отображения
# Graphics object consisting of 103 graphics primitives

# %% [markdown]
# Бусины действительно симметрично отобразились

# %%
print('Применим операцию поворота два раза и выведем результат')
print_necklace(tau(tau(start_necklace)))
# Out:
# Применим операцию поворота два раза и выведем результат
# Graphics object consisting of 103 graphics primitives

# %% [markdown]
# Видно, что все бусины сместились на две позиции по часовой стрелке, как и должно быть

# %%
print('Повернём бусы и симметрично отобразим')
print_necklace(sigma(tau(start_necklace)))
# Out:
# Повернём бусы и симметрично отобразим
# Graphics object consisting of 103 graphics primitives

# %% [markdown]
# Видно, что бусина 1 осталась на своём месте, а остальные симметрично отобразились

# %% [markdown]
# ## Вывод по работе
# Было сформировано представление решения задачи о раскрасках, выработано умение использования леммы Бёрнсайда для решения данной задачи, были изучены возможности системы компьютерной алгебры $SageMath$ для графического отображения решения данной задачи.
